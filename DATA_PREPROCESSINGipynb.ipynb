# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/JNK.csv')
data
# Out:
#             Date        Open        High         Low       Close  Adj Close  \
# 0     2014-01-02  121.800003  121.800003  121.410004  121.589996  67.203178
# 1     2014-01-03  121.739998  121.860001  121.620003  121.680000  67.252922
# 2     2014-01-06  121.919998  122.010002  121.769997  121.919998  67.385567
# 3     2014-01-07  121.980003  122.070000  121.919998  121.949997  67.402176
# 4     2014-01-08  121.860001  122.010002  121.860001  121.919998  67.385567
# ...          ...         ...         ...         ...         ...        ...
# 2597  2024-04-29   93.769997   94.019997   93.769997   94.019997  93.477592
# 2598  2024-04-30   93.720001   93.919998   93.379997   93.430000  92.890999
# 2599  2024-05-01   92.849998   93.699997   92.849998   93.300003  93.300003
# 2600  2024-05-02   93.500000   93.870003   93.320000   93.839996  93.839996
# 2601  2024-05-03   94.330002   94.660004   94.089996   94.269997  94.269997
#
#         Volume
# 0      1422267
# 1       763967
# ...

# %%
data1 = pd.read_csv('/content/drive/MyDrive/GDPC1.csv')

# %%
data1
# Out:
#           DATE      GDPC1
# 0   2004-01-01  15248.680
# 1   2004-04-01  15366.850
# 2   2004-07-01  15512.619
# 3   2004-10-01  15670.880
# 4   2005-01-01  15844.727
# ..         ...        ...
# 76  2023-01-01  22112.329
# 77  2023-04-01  22225.350
# 78  2023-07-01  22490.692
# 79  2023-10-01  22679.255
# 80  2024-01-01  22768.866
#
# [81 rows x 2 columns]

# %%
data2 = pd.read_csv('/content/drive/MyDrive/FEDFUNDS.csv')
data2
# Out:
#            DATE  FEDFUNDS
# 0    2014-01-01      0.07
# 1    2014-02-01      0.07
# 2    2014-03-01      0.08
# 3    2014-04-01      0.09
# 4    2014-05-01      0.09
# ..          ...       ...
# 119  2023-12-01      5.33
# 120  2024-01-01      5.33
# 121  2024-02-01      5.33
# 122  2024-03-01      5.33
# 123  2024-04-01      5.33
#
# [124 rows x 2 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'])
data1['Date'] = pd.to_datetime(data1['DATE'])
data['GDP'] = None
for index, row in data.iterrows():
    date = row['Date']
    quarter_gdp = data1.loc[data1['Date'] <= date].iloc[-1]['GDPC1']
    data.at[index, 'GDP'] = quarter_gdp
data
# Out:
#            Date        Open        High         Low       Close  Adj Close  \
# 0    2014-01-02  121.800003  121.800003  121.410004  121.589996  67.203178
# 1    2014-01-03  121.739998  121.860001  121.620003  121.680000  67.252922
# 2    2014-01-06  121.919998  122.010002  121.769997  121.919998  67.385567
# 3    2014-01-07  121.980003  122.070000  121.919998  121.949997  67.402176
# 4    2014-01-08  121.860001  122.010002  121.860001  121.919998  67.385567
# ...         ...         ...         ...         ...         ...        ...
# 2597 2024-04-29   93.769997   94.019997   93.769997   94.019997  93.477592
# 2598 2024-04-30   93.720001   93.919998   93.379997   93.430000  92.890999
# 2599 2024-05-01   92.849998   93.699997   92.849998   93.300003  93.300003
# 2600 2024-05-02   93.500000   93.870003   93.320000   93.839996  93.839996
# 2601 2024-05-03   94.330002   94.660004   94.089996   94.269997  94.269997
#
#         Volume        GDP
# 0      1422267  17953.974
# ...

# %%
data2
# Out:
#            DATE  FEDFUNDS
# 0    2014-01-01      0.07
# 1    2014-02-01      0.07
# 2    2014-03-01      0.08
# 3    2014-04-01      0.09
# 4    2014-05-01      0.09
# ..          ...       ...
# 119  2023-12-01      5.33
# 120  2024-01-01      5.33
# 121  2024-02-01      5.33
# 122  2024-03-01      5.33
# 123  2024-04-01      5.33
#
# [124 rows x 2 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'])
data2['Date'] = pd.to_datetime(data2['DATE'])

data['FEDFUNDS'] = None
for index, row in data.iterrows():
    date = row['Date']
    month_gdp = data2.loc[data2['Date'].dt.to_period('M') == date.to_period('M')]['FEDFUNDS']
    if month_gdp.empty:
        month_gdp = data2.loc[data2['Date'] <= date].iloc[-1]['FEDFUNDS']
    else:
        month_gdp = month_gdp.iloc[0]
    data.at[index, 'FEDFUNDS'] = month_gdp
data
# Out:
#            Date        Open        High         Low       Close  Adj Close  \
# 0    2014-01-02  121.800003  121.800003  121.410004  121.589996  67.203178
# 1    2014-01-03  121.739998  121.860001  121.620003  121.680000  67.252922
# 2    2014-01-06  121.919998  122.010002  121.769997  121.919998  67.385567
# 3    2014-01-07  121.980003  122.070000  121.919998  121.949997  67.402176
# 4    2014-01-08  121.860001  122.010002  121.860001  121.919998  67.385567
# ...         ...         ...         ...         ...         ...        ...
# 2597 2024-04-29   93.769997   94.019997   93.769997   94.019997  93.477592
# 2598 2024-04-30   93.720001   93.919998   93.379997   93.430000  92.890999
# 2599 2024-05-01   92.849998   93.699997   92.849998   93.300003  93.300003
# 2600 2024-05-02   93.500000   93.870003   93.320000   93.839996  93.839996
# 2601 2024-05-03   94.330002   94.660004   94.089996   94.269997  94.269997
#
#         Volume        GDP FEDFUNDS
# ...

# %%
data3 = pd.read_csv('/content/drive/MyDrive/UNRATE (1).csv')

# %%
data3
# Out:
#            DATE  UNRATE
# 0    2014-01-01     6.6
# 1    2014-02-01     6.7
# 2    2014-03-01     6.7
# 3    2014-04-01     6.2
# 4    2014-05-01     6.3
# ..          ...     ...
# 119  2023-12-01     3.7
# 120  2024-01-01     3.7
# 121  2024-02-01     3.9
# 122  2024-03-01     3.8
# 123  2024-04-01     3.9
#
# [124 rows x 2 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'])
data3['Date'] = pd.to_datetime(data2['DATE'])

data['Unemployment rate'] = None

for index, row in data.iterrows():
    date = row['Date']

    month_gdp = data3.loc[data3['Date'].dt.to_period('M') == date.to_period('M')]['UNRATE']
    if month_gdp.empty:
        month_gdp = data3.loc[data3['Date'] <= date].iloc[-1]['UNRATE']
    else:
        month_gdp = month_gdp.iloc[0]
    data.at[index, 'Unemployment rate'] = month_gdp
data
# Out:
#            Date        Open        High         Low       Close  Adj Close  \
# 0    2014-01-02  121.800003  121.800003  121.410004  121.589996  67.203178
# 1    2014-01-03  121.739998  121.860001  121.620003  121.680000  67.252922
# 2    2014-01-06  121.919998  122.010002  121.769997  121.919998  67.385567
# 3    2014-01-07  121.980003  122.070000  121.919998  121.949997  67.402176
# 4    2014-01-08  121.860001  122.010002  121.860001  121.919998  67.385567
# ...         ...         ...         ...         ...         ...        ...
# 2597 2024-04-29   93.769997   94.019997   93.769997   94.019997  93.477592
# 2598 2024-04-30   93.720001   93.919998   93.379997   93.430000  92.890999
# 2599 2024-05-01   92.849998   93.699997   92.849998   93.300003  93.300003
# 2600 2024-05-02   93.500000   93.870003   93.320000   93.839996  93.839996
# 2601 2024-05-03   94.330002   94.660004   94.089996   94.269997  94.269997
#
#         Volume        GDP FEDFUNDS Unemployment rate
# ...

# %%
data4 = pd.read_csv('/content/drive/MyDrive/PRICES_CPI_03052024234029892.csv')
data4
# Out:
#       LOCATION        Country   SUBJECT  \
# 0          USA  United States  CP030000
# 1          USA  United States  CP030000
# 2          USA  United States  CP030000
# 3          USA  United States  CP030000
# 4          USA  United States  CP030000
# ...        ...            ...       ...
# 19435      USA  United States  CP070200
# 19436      USA  United States  CP070200
# 19437      USA  United States  CP070200
# 19438      USA  United States  CP070200
# 19439      USA  United States  CP070200
#
#                                                  Subject MEASURE  \
# 0                        CPI: 03 - Clothing and footwear      GP
# 1                        CPI: 03 - Clothing and footwear      GP
# 2                        CPI: 03 - Clothing and footwear      GP
# 3                        CPI: 03 - Clothing and footwear      GP
# 4                        CPI: 03 - Clothing and footwear      GP
# ...                                                  ...     ...
# ...

# %%
data4.columns
# Out:
# Index(['LOCATION', 'Country', 'SUBJECT', 'Subject', 'MEASURE', 'Measure',
#        'FREQUENCY', 'Frequency', 'TIME', 'Time', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags', 'Date'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])
data4['Date'] = pd.to_datetime(data4['TIME'])
data['Inflation'] = None

for index, row in data.iterrows():
    date = row['Date']
    month_gdp = data4.loc[data4['Date'].dt.to_period('M') == date.to_period('M')]['Value']
    if month_gdp.empty:
        month_gdp = data4.loc[data4['Date'] <= date].iloc[-1]['Value']
    else:
        month_gdp = month_gdp.iloc[0]
    data.at[index, 'Inflation'] = month_gdp

data
# Out:
#            Date        Open        High         Low       Close  Adj Close  \
# 0    2014-01-02  121.800003  121.800003  121.410004  121.589996  67.203178
# 1    2014-01-03  121.739998  121.860001  121.620003  121.680000  67.252922
# 2    2014-01-06  121.919998  122.010002  121.769997  121.919998  67.385567
# 3    2014-01-07  121.980003  122.070000  121.919998  121.949997  67.402176
# 4    2014-01-08  121.860001  122.010002  121.860001  121.919998  67.385567
# ...         ...         ...         ...         ...         ...        ...
# 2597 2024-04-29   93.769997   94.019997   93.769997   94.019997  93.477592
# 2598 2024-04-30   93.720001   93.919998   93.379997   93.430000  92.890999
# 2599 2024-05-01   92.849998   93.699997   92.849998   93.300003  93.300003
# 2600 2024-05-02   93.500000   93.870003   93.320000   93.839996  93.839996
# 2601 2024-05-03   94.330002   94.660004   94.089996   94.269997  94.269997
#
#         Volume        GDP FEDFUNDS Unemployment rate Inflation
# ...

# %%
# Save the combined dataset to a CSV file
data.to_csv("SPDR Bloomberg High Yield Bond ETF (JNK).csv", index=True)
